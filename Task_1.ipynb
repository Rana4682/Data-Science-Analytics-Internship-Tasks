# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Iris.csv')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
 df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.figure(figsize=(150,6))

# %%
df=sns.load_dataset('iris')

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.title('Scatter Plot: Sepal Length vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Scatter Plot: Sepal Length vs Sepal Width')

# %%
plt.xlabel('Sepal Length')
# Out:
# Text(0.5, 0, 'Sepal Length')

# %%
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
plt.grid(True)

# %%
plt.show()

# %%
plt.figure(figsize=(150, 6))

# %%
plt.hist(df['petal_length'], bins=15, edgecolor='black')
# Out:
# (array([11., 37.,  2.,  0.,  0.,  3.,  4., 12., 18., 17., 16., 14., 10.,
#          2.,  4.]),
#  array([1.        , 1.39333333, 1.78666667, 2.18      , 2.57333333,
#         2.96666667, 3.36      , 3.75333333, 4.14666667, 4.54      ,
#         4.93333333, 5.32666667, 5.72      , 6.11333333, 6.50666667,
#         6.9       ]),
#  <BarContainer object of 15 artists>)

# %%
plt.title('Histogram of Petal Length')
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Length')

# %%
plt.xlabel('Petal Length')
# Out:
# Text(0.5, 0, 'Petal Length')

# %%
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(150, 6))

# %%
sns.boxplot(x='species', y='sepal_length', data=df, palette='Set2')
# Out:
# <ipython-input-29-2834611224>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_length', data=df, palette='Set2')
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
plt.title('Box Plot: Sepal Length by Species')
# Out:
# Text(0.5, 1.0, 'Box Plot: Sepal Length by Species')

# %%
plt.xlabel('Species')
# Out:
# Text(0.5, 0, 'Species')

# %%
from google.colab import files
files.download('/content/Iris.csv')
